# %% [markdown]
# <a href="https://colab.research.google.com/github/artamaral/Oreilly_curls/blob/main/Oreilly_Curls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

cookies = {
    'JSESSIONID': '16C53B8FC3D5C95DE467EEBF20BBF929-n1',
    'ga_session': '90e42a50-a579-4162-a68b-8ce88ffef1dd',
    'ActiveID': 'BAPN-B0RL-Y7FU-P057-CLAO-HOXR-AMJX-SQLS',
    'cust_id': '"51pJDv8+72A5rvbLl1fRmNuPF+TK6JqlLr3MPoXJJsA="',
    'OSESSIONID': '"ee2d7cb4903319a7"',
    'dtCookie': 'v_4_srv_13_sn_BA935FF3FF744956433C6FE16EE33031_perc_42497_ol_0_mul_3_app-3A200c4c21b0fea6c6_1',
    'akacd_ost-prod-lb-2': '1728357400~rv=51~id=e40ce334e69b9a0b917d3b08fe47ebef',
    'rxVisitor': '1728314200660UPUG5PD6IB5AR9TVCI7D9R2U4IBBLOM9',
    'mt.v': '2.1831519809.1728314200889',
    'NoCookie': 'true',
    '__pdst': '79f5d16e34874035a99605ffff81d994',
    '__wid': '362585101',
    '_gid': 'GA1.2.26664875.1728314203',
    'uws_storage': '%22cookie%22',
    'LPVID': 'U4NjM0ZjQ1ZThjODQ0OGVh',
    'AKA_A2': 'A',
    'uws_prop_8swyp7jh': '%22N%2FA%22%7Csession_timeout',
    'uws_prop_5lcxgghj': '%22N%2FA%22%7Csession_timeout',
    'uws_prop_q8ub7x2l': '%22N%2FA%22%7Csession_timeout',
    'uws_prop_vn35otqo': '%22N%2FA%22%7Csession_timeout',
    'uws_prop_8jo1u2t0': '%2290e42a50-a579-4162-a68b-8ce88ffef1dd%22%7Csession_timeout',
    'uws_rate_comparators': '%7B%22global%22%3A72754392%7D%7Csession_timeout',
    'LPSID-16349016': 'UOBoCMSaQL2R-tKCsMlCnw',
    'uws_recording': '%7B%22status%22%3A%22recording%22%2C%22conditional%22%3Atrue%2C%22requestActivation%22%3Afalse%2C%22recordingType%22%3Anull%7D%7Csession_timeout',
    'BVImplmain_site': '14810',
    'truyoConsent': '{"consumerCookieId":"a484adf6-e6ba-4c74-a931-e1ef8afd1fde","consentRecordDate":"2024-10-07T16:55:52.574Z","consentRevision":"1.0","flag":1,"Functionality Cookies":"1","Strictly Necessary Cookies":"1","Targeting and Advertising Cookies":"1","Tracking and Performance Cookies":"1","displayCookieBar":"true"}',
    'selectedStoreId': '3361',
    'lat': '42.779224',
    'lng': '-83.23864',
    'uws_prop_w71w8mxp': '%223361%7C375%20South%20Broadway%7CLake%20Orion%7CMI%22%7Csession_timeout',
    'EPCRVP': '"PTQ-DMF167395,cc087bdf6875|PTQ-NFW6605"',
    '_abck': '93D8DEB6EAB3A2B25CFAFEA353E8AF10~0~...~-1~-1~-1',
    'bm_sz': 'A02482CF2F0B0D1BC8EF3128D678C710~...~3228982~3159604',
    'forterToken': '59eb71d5a7e4407ab7704a16ff795b86_1728320719693__UDF43_13ck',
    'uws_session': '%7B%22start%22%3A1728319259167%2C%22count%22%3A12%2C%22referrer%22%3A%22www.oreillyauto.com%2Fshop%2Fb%2Fengines---transmissions%2Ftransmission---transaxle%2F642718e250f3%22%7D%7Csession_timeout',
    'uws_visitor': '%7B%22vid%22%3A%22172831420318949395%22%2C%22start%22%3A1728314203188%2C%22count%22%3A13%7D%7C1736096720482',
    'rxvt': '1728322524697|1728319047519',
    'dtPC': '13$320719441_770h-vAVDMOKJKCANAHFHKTKPCMNOJMLFHJPOU-0e0',
    '_ga': 'GA1.2.209920118.1728314203',
    '_gat_UA-1862090-1': '1',
    '_ga_TV3LS85R98': 'GS1.1.1728319253.2.1.1728321889.0.0.0',
    'dtSa': 'true%7CC%7C-1%7CdTMasked_BUTTON%7C-%7C1728321889420%7C320719441_770%7Chttps%3A%2F%2Fwww.oreillyauto.com%2Fsearch%3Fq%3DK7016501%7C%7C%7C%7C',
    'RT': '"z=1&dm=oreillyauto.com&si=bi02dlcuu2&ss=m1z8nqq9&sl=c&tt=168z&obo=3&nu=505db4eb8da54b15bd04cdd2d94a81a9&cl=1ki2w&ld=1ki3p&r=9398304d5070c651485d52cfe007d83c&ul=1ki3q"',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
    # 'cookie': 'JSESSIONID=16C53B8FC3D5C95DE467EEBF20BBF929-n1; ga_session=90e42a50-a579-4162-a68b-8ce88ffef1dd; ActiveID=BAPN-B0RL-Y7FU-P057-CLAO-HOXR-AMJX-SQLS; cust_id="51pJDv8+72A5rvbLl1fRmNuPF+TK6JqlLr3MPoXJJsA="; OSESSIONID="ee2d7cb4903319a7"; dtCookie=v_4_srv_13_sn_BA935FF3FF744956433C6FE16EE33031_perc_42497_ol_0_mul_3_app-3A200c4c21b0fea6c6_1; akacd_ost-prod-lb-2=1728357400~rv=51~id=e40ce334e69b9a0b917d3b08fe47ebef; rxVisitor=1728314200660UPUG5PD6IB5AR9TVCI7D9R2U4IBBLOM9; mt.v=2.1831519809.1728314200889; NoCookie=true; __pdst=79f5d16e34874035a99605ffff81d994; __wid=362585101; _gid=GA1.2.26664875.1728314203; uws_storage=%22cookie%22; LPVID=U4NjM0ZjQ1ZThjODQ0OGVh; AKA_A2=A; uws_prop_8swyp7jh=%22N%2FA%22%7Csession_timeout; uws_prop_5lcxgghj=%22N%2FA%22%7Csession_timeout; uws_prop_q8ub7x2l=%22N%2FA%22%7Csession_timeout; uws_prop_vn35otqo=%22N%2FA%22%7Csession_timeout; uws_prop_8jo1u2t0=%2290e42a50-a579-4162-a68b-8ce88ffef1dd%22%7Csession_timeout; uws_rate_comparators=%7B%22global%22%3A72754392%7D%7Csession_timeout; LPSID-16349016=UOBoCMSaQL2R-tKCsMlCnw; uws_recording=%7B%22status%22%3A%22recording%22%2C%22conditional%22%3Atrue%2C%22requestActivation%22%3Afalse%2C%22recordingType%22%3Anull%7D%7Csession_timeout; BVImplmain_site=14810; truyoConsent={"consumerCookieId":"a484adf6-e6ba-4c74-a931-e1ef8afd1fde","consentRecordDate":"2024-10-07T16:55:52.574Z","consentRevision":"1.0","flag":1,"Functionality Cookies":"1","Strictly Necessary Cookies":"1","Targeting and Advertising Cookies":"1","Tracking and Performance Cookies":"1","displayCookieBar":"true"}; selectedStoreId=3361; lat=42.779224; lng=-83.23864; uws_prop_w71w8mxp=%223361%7C375%20South%20Broadway%7CLake%20Orion%7CMI%22%7Csession_timeout; EPCRVP="PTQ-DMF167395,cc087bdf6875|PTQ-NFW6605"; _abck=93D8DEB6EAB3A2B25CFAFEA353E8AF10~0~...~-1~-1~-1; bm_sz=A02482CF2F0B0D1BC8EF3128D678C710~...~3228982~3159604; forterToken=59eb71d5a7e4407ab7704a16ff795b86_1728320719693__UDF43_13ck; uws_session=%7B%22start%22%3A1728319259167%2C%22count%22%3A12%2C%22referrer%22%3A%22www.oreillyauto.com%2Fshop%2Fb%2Fengines---transmissions%2Ftransmission---transaxle%2F642718e250f3%22%7D%7Csession_timeout; uws_visitor=%7B%22vid%22%3A%22172831420318949395%22%2C%22start%22%3A1728314203188%2C%22count%22%3A13%7D%7C1736096720482; rxvt=1728322524697|1728319047519; dtPC=13$320719441_770h-vAVDMOKJKCANAHFHKTKPCMNOJMLFHJPOU-0e0; _ga=GA1.2.209920118.1728314203; _gat_UA-1862090-1=1; _ga_TV3LS85R98=GS1.1.1728319253.2.1.1728321889.0.0.0; dtSa=true%7CC%7C-1%7CdTMasked_BUTTON%7C-%7C1728321889420%7C320719441_770%7Chttps%3A%2F%2Fwww.oreillyauto.com%2Fsearch%3Fq%3DK7016501%7C%7C%7C%7C; RT="z=1&dm=oreillyauto.com&si=bi02dlcuu2&ss=m1z8nqq9&sl=c&tt=168z&obo=3&nu=505db4eb8da54b15bd04cdd2d94a81a9&cl=1ki2w&ld=1ki3p&r=9398304d5070c651485d52cfe007d83c&ul=1ki3q"',
    'priority': 'u=0, i',
    'referer': 'https://www.oreillyauto.com/search?q=K7016501',
    'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
}

params = {
    'q': 'NFW2003',
}

response = requests.get('https://www.oreillyauto.com/search', params=params, cookies=cookies, headers=headers)

# %%
response.text
# Out:
# '<!DOCTYPE html>\n\n<html class="no-js no-flexbox" lang="en">\n    <head>\n        <script>window._ost = {}</script>\n<meta charset="utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\n    <title>Search for NFW2003 | O&#39;Reilly Auto Parts</title>\n    <meta name="title" content="Search for NFW2003 | O&#39;Reilly Auto Parts" />\n\n\n\n\n\n    <meta name="description" content="Order the best NFW2003 for your vehicle and pick it up in store today. Free shipping is available on most online orders." />\n\n\n\n\n<link rel="canonical" href="https://ost-honeypot-1.oreillyauto.com/search" />\n<meta name="viewport" content="width=device-width, initial-scale=1" />\n\n\n\n<link rel="apple-touch-icon" href="/img/apple-touch-icon.png" />\n\n<meta name="facebook-domain-verification" />\n\n<script defer="defer" src="//maps.googleapis.com/maps/api/js?key=AIzaSyBMQerlqd7MDfuKhvW1bstEXHUd13tddxo&amp;v=3&amp;libraries=places"></script>\n\n\n<script>\n    /*<![CDATA[*/\n    var ignore
# ...

# %%
# prompt: usar um html como entrara e extrair dados de </script> usando bs4

from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text, 'html.parser')

script_tags = soup.find_all('script')

x=0
for script in script_tags:
  # Extrai o conteúdo do script
  script_content = script.string


  if(x==28):
    print(script_content)
    Alldata = script_content
  x=x+1

  #if script_content:
    # Processa o conteúdo do script (por exemplo, procurar dados específicos)
    # ...
    #print(script_content)

# %%
name =[]
lineCodeItemNumber = []
pricing = []

for data in Alldata.split('\n'):
  if "_name" in data:
    print(data.split("=")[1].replace(';', '').replace("'", ''))
    name.append(data.split("=")[1].replace(';', '').replace("'", ''))

  if "_lineCodeItemNumber`" in data:
    print(data.split("=")[1].replace(';', ''))
    new_data = data.split("=")[1].replace(';', '').replace("'", '"')
    new_data = json.loads(new_data)
    print(new_data['itemNumber'])
    lineCodeItemNumber.append(new_data['itemNumber'])


  if "_pricing`" in data:
    print(data.split("=")[1].replace(';', ''))
    new_data = data.split("=")[1].replace(';', '').replace("'", '"')
    new_data = json.loads(new_data)
    print(new_data['price'])
    pricing.append(new_data['price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-945f2ef0de84> in <cell line: 5>()
#       3 pricing = []
#       4
# ----> 5 for data in Alldata.split('\n'):
#       6   if "_name" in data:
#       7     print(data.split("=")[1].replace(';', '').replace("'", ''))
#
# NameError: name 'Alldata' is not defined

# %%
import pandas as pd
Allinfo = pd.DataFrame()
Allinfo['name'] = name
Allinfo['lineCodeItemNumber'] = lineCodeItemNumber
Allinfo['pricing'] = pricing
Allinfo
# Out:
# Empty DataFrame
# Columns: [name, lineCodeItemNumber, pricing]
# Index: []

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json

# %% [markdown]
# Incluir o arquivo na pasta do colab

# %%
# prompt: importar o arquivo Untitled spreadsheet - Data to lookup csv iterar sobre ele e salvar cada valor em uma lista
def listPN():
  '''
  df.to_numpy(): Converts the DataFrame to a NumPy array.
  .flatten(): Transforms the multi-dimensional array into a 1-dimensional array.
  .tolist(): Converts the flattened NumPy array into a Python list.
  '''
  # Importar o arquivo CSV
  df = pd.read_csv('Untitled spreadsheet - Data to lookup2.csv')
  list_df = df.to_numpy().flatten().tolist()
  return list_df

# %%
def getHtml(pn):



  cookies = {
      'JSESSIONID': '16C53B8FC3D5C95DE467EEBF20BBF929-n1',
      'ga_session': '90e42a50-a579-4162-a68b-8ce88ffef1dd',
      'ActiveID': 'BAPN-B0RL-Y7FU-P057-CLAO-HOXR-AMJX-SQLS',
      'cust_id': '"51pJDv8+72A5rvbLl1fRmNuPF+TK6JqlLr3MPoXJJsA="',
      'OSESSIONID': '"ee2d7cb4903319a7"',
      'dtCookie': 'v_4_srv_13_sn_BA935FF3FF744956433C6FE16EE33031_perc_42497_ol_0_mul_3_app-3A200c4c21b0fea6c6_1',
      'akacd_ost-prod-lb-2': '1728357400~rv=51~id=e40ce334e69b9a0b917d3b08fe47ebef',
      'rxVisitor': '1728314200660UPUG5PD6IB5AR9TVCI7D9R2U4IBBLOM9',
      'mt.v': '2.1831519809.1728314200889',
      'NoCookie': 'true',
      '__pdst': '79f5d16e34874035a99605ffff81d994',
      '__wid': '362585101',
      '_gid': 'GA1.2.26664875.1728314203',
      'uws_storage': '%22cookie%22',
      'LPVID': 'U4NjM0ZjQ1ZThjODQ0OGVh',
      'uws_prop_8swyp7jh': '%22N%2FA%22%7Csession_timeout',
      'uws_prop_5lcxgghj': '%22N%2FA%22%7Csession_timeout',
      'uws_prop_q8ub7x2l': '%22N%2FA%22%7Csession_timeout',
      'uws_prop_vn35otqo': '%22N%2FA%22%7Csession_timeout',
      'uws_prop_8jo1u2t0': '%2290e42a50-a579-4162-a68b-8ce88ffef1dd%22%7Csession_timeout',
      'uws_rate_comparators': '%7B%22global%22%3A72754392%7D%7Csession_timeout',
      'uws_recording': '%7B%22status%22%3A%22recording%22%2C%22conditional%22%3Atrue%2C%22requestActivation%22%3Afalse%2C%22recordingType%22%3Anull%7D%7Csession_timeout',
      'BVImplmain_site': '14810',
      'truyoConsent': '{"consumerCookieId":"a484adf6-e6ba-4c74-a931-e1ef8afd1fde","consentRecordDate":"2024-10-07T16:55:52.574Z","consentRevision":"1.0","flag":1,"Functionality Cookies":"1","Strictly Necessary Cookies":"1","Targeting and Advertising Cookies":"1","Tracking and Performance Cookies":"1","displayCookieBar":"true"}',
      'selectedStoreId': '3361',
      'lat': '42.779224',
      'lng': '-83.23864',
      'uws_prop_w71w8mxp': '%223361%7C375%20South%20Broadway%7CLake%20Orion%7CMI%22%7Csession_timeout',
      'EPCRVP': '"PTQ-DMF167395,cc087bdf6875|PTQ-NFW6605"',
      'AKA_A2': 'A',
      'bm_sz': '4A7204D8225DA569569BE5644466233A~...~3228211~3748163',
      '_abck': '93D8DEB6EAB3A2B25CFAFEA353E8AF10~0~...~-1~||0||~-1',
      'forterToken': '59eb71d5a7e4407ab7704a16ff795b86_1728336192011__UDF43_13ck',
      'uws_session': '%7B%22start%22%3A1728319259167%2C%22count%22%3A17%2C%22referrer%22%3A%22www.oreillyauto.com%2Fshop%2Fb%2Fengines---transmissions%2Ftransmission---transaxle%2F642718e250f3%22%7D%7Csession_timeout',
      'uws_visitor': '%7B%22vid%22%3A%22172831420318949395%22%2C%22start%22%3A1728314203188%2C%22count%22%3A18%7D%7C1736112193020',
      'LPSID-16349016': '_avOjuMgQmC18VAmmTPpaA',
      '_ga': 'GA1.2.209920118.1728314203',
      '_ga_TV3LS85R98': 'GS1.1.1728336190.5.1.1728336196.0.0.0',
      'dtPC': '13$336191479_49h-vISSKNBERONULGUIFPRACCGPHCQBQUGMR-0e0',
      'rxvt': '1728339797312|1728337997312',
      'dtSa': 'true%7CKD%7C-1%7CdTMasked_BODY%7C-%7C1728338123395%7C336191479_49%7Chttps%3A%2F%2Fwww.oreillyauto.com%2Fsearch%3Fq%3DK7027801%7C%7C%7C%7C',
      'RT': '"z=1&dm=oreillyauto.com&si=9apjdkxyad&ss=m1z8nqq9&sl=h&tt=1fdd&obo=6&ld=b8gaw&r=7608532c526463f80e45bf15d83d52d7&ul=b8gax"',
  }

  headers = {
      'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
      'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
      'cache-control': 'max-age=0',
      # 'cookie': 'JSESSIONID=16C53B8FC3D5C95DE467EEBF20BBF929-n1; ga_session=90e42a50-a579-4162-a68b-8ce88ffef1dd; ActiveID=BAPN-B0RL-Y7FU-P057-CLAO-HOXR-AMJX-SQLS; cust_id="51pJDv8+72A5rvbLl1fRmNuPF+TK6JqlLr3MPoXJJsA="; OSESSIONID="ee2d7cb4903319a7"; dtCookie=v_4_srv_13_sn_BA935FF3FF744956433C6FE16EE33031_perc_42497_ol_0_mul_3_app-3A200c4c21b0fea6c6_1; akacd_ost-prod-lb-2=1728357400~rv=51~id=e40ce334e69b9a0b917d3b08fe47ebef; rxVisitor=1728314200660UPUG5PD6IB5AR9TVCI7D9R2U4IBBLOM9; mt.v=2.1831519809.1728314200889; NoCookie=true; __pdst=79f5d16e34874035a99605ffff81d994; __wid=362585101; _gid=GA1.2.26664875.1728314203; uws_storage=%22cookie%22; LPVID=U4NjM0ZjQ1ZThjODQ0OGVh; uws_prop_8swyp7jh=%22N%2FA%22%7Csession_timeout; uws_prop_5lcxgghj=%22N%2FA%22%7Csession_timeout; uws_prop_q8ub7x2l=%22N%2FA%22%7Csession_timeout; uws_prop_vn35otqo=%22N%2FA%22%7Csession_timeout; uws_prop_8jo1u2t0=%2290e42a50-a579-4162-a68b-8ce88ffef1dd%22%7Csession_timeout; uws_rate_comparators=%7B%22global%22%3A72754392%7D%7Csession_timeout; uws_recording=%7B%22status%22%3A%22recording%22%2C%22conditional%22%3Atrue%2C%22requestActivation%22%3Afalse%2C%22recordingType%22%3Anull%7D%7Csession_timeout; BVImplmain_site=14810; truyoConsent={"consumerCookieId":"a484adf6-e6ba-4c74-a931-e1ef8afd1fde","consentRecordDate":"2024-10-07T16:55:52.574Z","consentRevision":"1.0","flag":1,"Functionality Cookies":"1","Strictly Necessary Cookies":"1","Targeting and Advertising Cookies":"1","Tracking and Performance Cookies":"1","displayCookieBar":"true"}; selectedStoreId=3361; lat=42.779224; lng=-83.23864; uws_prop_w71w8mxp=%223361%7C375%20South%20Broadway%7CLake%20Orion%7CMI%22%7Csession_timeout; EPCRVP="PTQ-DMF167395,cc087bdf6875|PTQ-NFW6605"; AKA_A2=A; bm_sz=4A7204D8225DA569569BE5644466233A~...~3228211~3748163; _abck=93D8DEB6EAB3A2B25CFAFEA353E8AF10~0~...~-1~||0||~-1; forterToken=59eb71d5a7e4407ab7704a16ff795b86_1728336192011__UDF43_13ck; uws_session=%7B%22start%22%3A1728319259167%2C%22count%22%3A17%2C%22referrer%22%3A%22www.oreillyauto.com%2Fshop%2Fb%2Fengines---transmissions%2Ftransmission---transaxle%2F642718e250f3%22%7D%7Csession_timeout; uws_visitor=%7B%22vid%22%3A%22172831420318949395%22%2C%22start%22%3A1728314203188%2C%22count%22%3A18%7D%7C1736112193020; LPSID-16349016=_avOjuMgQmC18VAmmTPpaA; _ga=GA1.2.209920118.1728314203; _ga_TV3LS85R98=GS1.1.1728336190.5.1.1728336196.0.0.0; dtPC=13$336191479_49h-vISSKNBERONULGUIFPRACCGPHCQBQUGMR-0e0; rxvt=1728339797312|1728337997312; dtSa=true%7CKD%7C-1%7CdTMasked_BODY%7C-%7C1728338123395%7C336191479_49%7Chttps%3A%2F%2Fwww.oreillyauto.com%2Fsearch%3Fq%3DK7027801%7C%7C%7C%7C; RT="z=1&dm=oreillyauto.com&si=9apjdkxyad&ss=m1z8nqq9&sl=h&tt=1fdd&obo=6&ld=b8gaw&r=7608532c526463f80e45bf15d83d52d7&ul=b8gax"',
      'priority': 'u=0, i',
      'referer': 'https://www.oreillyauto.com/search?q=NFW1007',
      'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'document',
      'sec-fetch-mode': 'navigate',
      'sec-fetch-site': 'same-origin',
      'sec-fetch-user': '?1',
      'upgrade-insecure-requests': '1',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
  }

  params = {
      'q': pn,
  }

  response = requests.get('https://www.oreillyauto.com/search', params=params, cookies=cookies, headers=headers)
  return response

# %%
def readHTML(response):

  soup = BeautifulSoup(response.text, 'html.parser')
  script_tags = soup.find_all('script')
  x=0

  name=""
  lineCodeItemNumber=""
  pricing=""

  for script in script_tags:

    # Extrai o conteúdo do script
    script_content = script.string

    if(x==28):

      Alldata = script_content
      listData =  Alldata.split('\n')

      for item in listData:

        if "_name" in item:
          #print(item.split("=")[1].replace(';', '').replace("'", ''))
          name = item.split("=")[1].replace(';', '').replace("'", '')

        if "_lineCodeItemNumber`" in item:
          #print(item.split("=")[1].replace(';', ''))
          new_data = item.split("=")[1].replace(';', '').replace("'", '"')
          new_data = json.loads(new_data)
          #print(new_data['itemNumber'])
          lineCodeItemNumber = new_data['itemNumber']

        if "_pricing`" in item:
          #print(item.split("=")[1].replace(';', ''))
          new_data = item.split("=")[1].replace(';', '').replace("'", '"')
          new_data = json.loads(new_data)
          #print(new_data['price'])
          pricing = new_data['price']

      return name, lineCodeItemNumber, pricing

    x=x+1

# %%
allData = pd.DataFrame()
allDatalist = []
pns = listPN()
for pn in pns:
  response = getHtml(pn)
  try:
    data = readHTML(response)
  except:
    print(f"Exception: no data {pn}")
  print(data)
  allDatalist.append(data)
allData = pd.DataFrame(allDatalist)
# Out:
# (' Power Torque Clutch Set ', 'K70396-01', 278.99)
# (' Power Torque Flywheel ', 'NFW1008', 76.99)
# (' Power Torque Clutch Set ', 'KF583-03', 108.99)
# (' Power Torque Clutch Set ', 'K1878-02', 140.99)
# (' Power Torque Clutch Set ', 'K0077-01', 169.99)
# (' Power Torque Clutch Set ', 'K70518-01', 481.99)
# (' Power Torque Clutch Set ', 'K70098-01', 103.99)
# (' Power Torque Clutch Set ', 'K0071-01', 73.99)
# (' Power Torque Clutch Set ', 'K70463-01', 340.99)
# (' Power Torque Clutch Set ', 'K70383-01', 579.99)
# (' Power Torque Clutch Set ', 'K70388-01', 459.99)
# (' Power Torque Clutch Set ', 'K70064-02', 179.99)
# (' Power Torque Clutch Set ', 'K70434-01', 748.99)
# (' Power Torque Flywheel ', 'NFW3614', 68.99)
# (' Power Torque Clutch Set ', 'K1878-03', 146.99)
# (' Power Torque Clutch Set ', 'K0076-05', 124.99)
# (' Power Torque Clutch Set ', 'K70315-01', 334.99)
# (' Power Torque Clutch Set ', 'KF621-03', 79.99)
# (' Power Torque Clutch Set ', 'K70370-01', 403.99)
# ...

# %%
allDatalist
allData = pd.DataFrame(allDatalist)
allData.to_csv('allData2.csv', index=False)
